# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/suriya/Downloads/LLMs and IUX Prompts.xlsx - Synthesized.csv")

# %%
df.head()
# Out:
#    SeedId                               SynthId  UtteranceIndex  \
# 0     NaN  b1875b96-1e2a-483e-866d-14cf95a6a876               0
# 1     NaN  b1875b96-1e2a-483e-866d-14cf95a6a876               1
# 2     NaN  b669daf3-17d4-485b-b90d-eb036178504f               0
# 3     NaN  b669daf3-17d4-485b-b90d-eb036178504f               1
# 4     NaN  8e42d80e-da9a-44c2-8213-964220ba460a               0
#
#                                            Utterance  Role      Type  \
# 0  What were the sales numbers for Men's Clothing...  User     query
# 1  Call Movement API with {"product-name" = "Men'...    AI  api_call
# 2  Can you give me the sales figures for Beauty p...  User     query
# 3  Call Movement API with {"product-name" = "Beau...    AI  api_call
# 4  I need to see the movement of Electronics in Z...  User     query
#
#                SythesizedBy  SynthesisTime        Category
# 0  Suriyadeepan Ramamoorthy            NaN  Movement/Sales
# 1  Suriyadeepan Ramamoorthy            NaN  Movement/Sales
# 2  Suriyadeepan Ramamoorthy            NaN  Movement/Sales
# 3  Suriyadeepan Ramamoorthy            NaN  Movement/Sales
# 4  Suriyadeepan Ramamoorthy            NaN  Movement/Sales

# %%
categories = df.Category.unique().tolist()
for category in categories:
    print(category)
    print("----------------")
    catdf = df[df.Category==category]
    sids = catdf.SynthId.unique().tolist()
    for sid in sids:
        udf = catdf[catdf.SynthId == sid].sort_values("UtteranceIndex")
        for i, row in udf.iterrows():
            print(f"{row.Role}: {row.Utterance}")
        print("\n")
    print("\n\n")
# Out:
# Movement/Sales
# ----------------
# User: What were the sales numbers for Men's Clothing in Zone 500 in Q3 of last year?
# AI: Call Movement API with {"product-name" = "Men's Clothing", "quarter" = 3, "metrics" = ["sales"], "location-name" = "Zone 500"}
#
#
# User: Can you give me the sales figures for Beauty products in Zone 1000 for the last six months?
# AI: Call Movement API with {"product-name" = "Beauty products", "quarter" = "last six months", "metrics" = ["sales"], "location-name" = "Zone 1000"}
#
#
# User: I need to see the movement of Electronics in Zone 250 for the last year.
# AI: Call Movement API with {"product-name" = "Electronics", "quarter" = "last year", "metrics" = ["movement"], "location-name" = "Zone 250"}
#
#
# User: How much revenue was generated from Home Decor in Zone 750 in the first quarter of this year?
# AI: Call Movement API with {"product-name" = "Home Decor", "quarter" = 1, "metrics" = ["sales"], "location-name" = "Zone 750"}
#
#
# User: What was the sales performance for Shoes in Zone 300 in Q4 of last year?
# AI: Call Movement API with {"product-name" = "Shoes", "quarter" = 4, "metrics" = ["sales"], "location-name" = "Zone 300"}
#
#
# User: Can you provide me with the sales data for Toys and Games in Zone 800 for the last six months?
# AI: Call Movement API with {"product-name" = "Toys and Games", "quarter" = "last six months", "metrics" = ["sales"], "location-name" = "Zone 800"}
#
#
# User: What were the quarterly sales figures for Sports Equipment in Zone 400?
# AI: Call Movement API with {"product-name" = "Sports Equipment", "quarter" = "quarterly", "metrics" = ["sales"], "location-name" = "Zone 400"}
#
#
# User: I want to see the sales numbers for Outdoor Gear in Zone 900 for the first half of this year.
# AI: Call Movement API with {"product-name" = "Outdoor Gear", "quarter" = "first half of the year", "metrics" = ["sales"], "location-name" = "Zone 900"}
#
#
# User: Please give me the sales performance of Pet Supplies in Zone 150 for Q2 and Q3 of last year.
# AI: Call Movement API with {"product-name" = "Pet Supplies", "quarter" = ["Q2", "Q3"], "metrics" = ["sales"], "location-name" = "Zone 150"}
#
#
# User: What was the revenue generated from Jewelry sales in Zone 600 in the last year?
# AI: Call Movement API with {"product-name" = "Jewelry sales", "quarter" = "last year", "metrics" = ["sales"], "location-name" = "Zone 600"}
#
#
#
#
#
# Budget/Forecast
# ----------------
# User: What are the sales targets for Snacks in Zone 35 for the next quarter?
# AI: Call Budget API with {"product-name" = "Snacks", "quarter" = "next", "location-name" = "Zone 35"} and Call Forecast API with {"product-name" = "Snacks", "quarter" = "next", "location-name" = "Zone 35"}
#
#
# User: Can you tell me the budget goals for Frozen Foods for the entire year?
# AI: Call Budget API with {"product-name" = "Frozen Foods", "quarter" = "yearly", "location-name" = "all"} and Call Forecast API with {"product-name" = "Frozen Foods", "quarter" = "yearly", "location-name" = "all"}
#
#
# User: What is the projected revenue for Beverages in Zone 20 for the next six months?
# AI: Call Budget API with {"product-name" = "Beverages", "quarter" = "next-6-months", "location-name" = "Zone 20"} and Call Forecast API with {"product-name" = "Beverages", "quarter" = "next-6-months", "location-name" = "Zone 20"}
#
#
# User: How are we performing in terms of meeting the budget targets for Bakery products in the current quarter?
# AI: Call Budget API with {"product-name" = "Bakery products", "quarter" = "current", "location-name" = "all"} and Call Forecast API with {"product-name" = "Bakery products", "quarter" = "current", "location-name" = "all"}
#
#
# User: What are the financial goals for Meat and Poultry for the upcoming year?
# AI: Call Budget API with {"product-name" = "Meat and Poultry", "quarter" = "upcoming-year", "location-name" = "all"} and Call Forecast API with {"product-name" = "Meat and Poultry", "quarter" = "upcoming-year", "location-name" = "all"}
#
#
# User: Can you provide me with the budget projections for Produce in Zone 450 for the next quarter?
# AI: Call Budget API with {"product-name" = "Produce", "quarter" = "next", "location-name" = "Zone 450"} and Call Forecast API with {"product-name" = "Produce", "quarter" = "next", "location-name" = "Zone 450"}
#
#
# User: What is the expected revenue for Seafood in the current quarter across all locations?
# AI: Call Budget API with {"product-name" = "Seafood", "quarter" = "current", "location-name" = "all"} and Call Forecast API with {"product-name" = "Seafood", "quarter" = "current", "location-name" = "all"}
#
#
# User: What are the sales targets for Canned Goods for the next six months in Zone 710?
# AI: Call Budget API with {"product-name" = "Canned Goods", "quarter" = "next-6-months", "location-name" = "Zone 710"} and Call Forecast API with {"product-name" = "Canned Goods", "quarter" = "next-6-months", "location-name" = "Zone 710"}
#
#
# User: How are we tracking against the budget goals for Deli products for the first half of the year?
# AI: Call Budget API with {"product-name" = "Deli products", "quarter" = "first-half", "location-name" = "all"} and Call Forecast API with {"product-name" = "Deli products", "quarter" = "first-half", "location-name" = "all"}
#
#
# User: Can you give me an update on the revenue projections for Dairy in Zone 880 for the next three months?
# AI: Call Budget API with {"product-name" = "Dairy", "quarter" = "next-3-months", "location-name" = "Zone 880"} and Call Forecast API with {"product-name" = "Dairy", "quarter" = "next-3-months", "location-name" = "Zone 880"}
#
#
#
#
#
# KVI
# ----------------
# User: What are the Secondary KVIs for Health and Wellness in Zone 15?
# AI: Call KVI API with {"product-name" = "Health and Wellness", "location-name" = "Zone 15", type = "Secondary"}
#
#
# User: Can you provide me with a list of the Top KVIs for Personal Care in Zone 35?
# AI: Call KVI API with {"product-name" = "Personal Care", "location-name" = "Zone 35", type = "Primary"}
#
#
# User: Give me the Primary KVIs for Baby Products in Zone 20.
# AI: Call KVI API with {"product-name" = "Baby Products", "location-name" = "Zone 20", type = "Primary"}
#
#
# User: What are the Top KVIs for Household Supplies in Zone 85?
# AI: Call KVI API with {"product-name" = "Household Supplies", "location-name" = "Zone 85", type = "Primary"}
#
#
# User: Can you give me a list of Secondary KVIs for Pet Care in Zone 710?
# AI: Call KVI API with {"product-name" = "Pet Care", "location-name" = "Zone 710", type = "Secondary"}
#
#
# User: What are the Primary KVIs for Beauty and Cosmetics in Zone 450?
# AI: Call KVI API with {"product-name" = "Beauty and Cosmetics", "location-name" = "Zone 450", type = "Primary"}
#
#
# User: Provide me with the Top KVIs for Toys and Games in Zone 880.
# AI: Call KVI API with {"product-name" = "Toys and Games", "location-name" = "Zone 880", type = "Primary"}
#
#
# User: What are the Secondary KVIs for Office Supplies in Zone 690?
# AI: Call KVI API with {"product-name" = "Office Supplies", "location-name" = "Zone 690", type = "Secondary"}
#
#
# User: Give me the Primary KVIs for Snacks and Confectionery in Zone 42.
# AI: Call KVI API with {"product-name" = "Snacks and Confectionery", "location-name" = "Zone 42", type = "Primary"}
#
#
# User: Can you provide me with a list of Top KVIs for Home Appliances in Zone 260?
# AI: Call KVI API with {"product-name" = "Home Appliances", "location-name" = "Zone 260", type = "Primary"}
#
#
#
#
#
# Price Change
# ----------------
# User: What are the products that have had a price change in the last two weeks for Snacks in Zone 15?
# AI: Call Cost API with {"product-name" = "Snacks", "location-name" = "Zone 15", week = "last 2", change = "Y"}
#
#
# User: Can you give me a list of all items with a cost change in the last month for Beauty and Cosmetics in Zone 35?
# AI: Call Cost API with {"product-name" = "Beauty and Cosmetics", "location-name" = "Zone 35", week = "last month", change = "Y"}
#
#
# User: Show me the products with a price change in the last week for Beverages in Zone 20.
# AI: Call Price API with {"product-name" = "Beverages", "location-name" = "Zone 20", week = "last week", change = "Y"}
#
#
# User: What are the items with a cost change in the last three weeks for Toys and Games in Zone 450?
# AI: Call Cost API with {"product-name" = "Toys and Games", "location-name" = "Zone 450", week = "last 3", change = "Y"}
#
#
# User: Can you provide me with a list of all products with a price change in the last four weeks for Frozen Foods in Zone 35?
# AI: Call Price API with {"product-name" = "Frozen Foods", "location-name" = "Zone 35", week = "last 4", change = "Y"}
#
#
# User: Show me all items with a cost change in the last two weeks for Home Appliances in Zone 880.
# AI: Call Cost API with {"product-name" = "Home Appliances", "location-name" = "Zone 880", week = "last 2", change = "Y"}
#
#
# User: What are the products that have had a price change in the last week for Meat and Poultry in Zone 450?
# AI: Call Price API with {"product-name" = "Meat and Poultry", "location-name" = "Zone 450", week = "last week", change = "Y"}
#
#
# User: Provide me with a list of all items with a cost change in the last month for Personal Care in Zone 15.
# AI: Call Cost API with {"product-name" = "Personal Care", "location-name" = "Zone 15", week = "last month", change = "Y"}
#
#
# User: Show me the products with a price change in the last three weeks for Office Supplies in Zone 690.
# AI: Call Price API with {"product-name" = "Office Supplies", "location-name" = "Zone 690", week = "last 3", change = "Y"}
#
#
# User: What are the items with a cost change in the last five days for Canned Goods in Zone 260?
# AI: Call Cost API with {"product-name" = "Canned Goods", "location-name" = "Zone 260", week = "last 5 days", change = "Y"}
#
#
#
#
#
# Promotions Percent
# ----------------
# User: What percentage of our Frozen Foods sales are from promotions in Zone 1?
# AI: Call Movement API with {"product-name" = "Frozen Foods", "location-name" = "Zone 1", metrics = ["sales"]} and Call Movement API with {"product-name" = "Frozen Foods", "location-name" = "Zone 1", metrics = ["sales"], "promo" = "Y"} and Call Calculator API with {"operation" = "division", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
#
# User: Can you tell me the percentage of sales from promotions for Dairy in Zone 35 in the last quarter?
# AI: Call Movement API with {"product-name" = "Dairy", "location-name" = "Zone 35", week = "last quarter", metrics = ["sales"]} and Call Movement API with {"product-name" = "Dairy", "location-name" = "Zone 35", week = "last quarter", metrics = ["sales"], "promo" = "Y"} and Call Calculator API with {"operation" = "division", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
#
# User: What % of our Meat and Poultry sales come from promotions for the entire year in Zone 1?
# AI: Call Movement API with {"product-name" = "Meat and Poultry", "location-name" = "Zone 1", week = "entire year", metrics = ["sales"]} and Call Movement API with {"product-name" = "Meat and Poultry", "location-name" = "Zone 1", week = "entire year", metrics = ["sales"], "promo" = "Y"} and Call Calculator API with {"operation" = "division", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
#
# User: How much of our sales for Canned Goods in Zone 50 are from promotions in the current quarter?
# AI: Call Movement API with {"product-name" = "Canned Goods", "location-name" = "Zone 50", week = "current quarter", metrics = ["sales"]} and Call Movement API with {"product-name" = "Canned Goods", "location-name" = "Zone 50", week = "current quarter", metrics = ["sales"], "promo" = "Y"} and Call Calculator API with {"operation" = "division", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
#
# User: What percentage of our Produce sales in Zone 20 are from promotions for the next six months?
# AI: Call Movement API with {"product-name" = "Produce", "location-name" = "Zone 20", week = "next 6 months", metrics = ["sales"]} and Call Movement API with {"product-name" = "Produce", "location-name" = "Zone 20", week = "next 6 months", metrics = ["sales"], "promo" = "Y"} and Call Calculator API with {"operation" = "division", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
#
# User: Can you provide me with the percentage of sales from promotions for Bakery products for the first half of the year in Zone 1?
# AI: Call Movement API with {"product-name" = "Bakery", "location-name" = "Zone 1", "start-date" = "01-01-YYYY", "end-date" = "06-30-YYYY", metrics = ["sales"]} and Call Movement API with {"product-name" = "Bakery", "location-name" = "Zone 1", "start-date" = "01-01-YYYY", "end-date" = "06-30-YYYY", metrics = ["sales"], "promo" = "Y"} and Call Calculator API with {"operation" = "division", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
#
# User: What % of our Seafood sales come from promotions in Zone 450 for the last quarter?
# AI: Call Movement API with {"product-name" = "Seafood", "location-name" = "Zone 450", "week" = "last quarter", metrics = ["sales"]} and Call Movement API with {"product-name" = "Seafood", "location-name" = "Zone 450", "week" = "last quarter", metrics = ["sales"], "promo" = "Y"} and Call Calculator API with {"operation" = "division", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
#
# User: How much of our Deli product sales are from promotions in the current month in Zone 1?
# AI: Call Movement API with {"product-name" = "Deli", "location-name" = "Zone 1", "week" = "current month", metrics = ["sales"]} and Call Movement API with {"product-name" = "Deli", "location-name" = "Zone 1", "week" = "current month", metrics = ["sales"], "promo" = "Y"} and Call Calculator API with {"operation" = "division", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
#
# User: What percentage of our sales for Snacks and Confectionery are from promotions in the last six months in Zone 710?
# AI: Call Movement API with {"product-name" = "Snacks and Confectionery", "location-name" = "Zone 710", "week" = "last six months", metrics = ["sales"]} and Call Movement API with {"product-name" = "Snacks and Confectionery", "location-name" = "Zone 710", "week" = "last six months", metrics = ["sales"], "promo" = "Y"} and Call Calculator API with {"operation" = "division", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
#
# User: Can you tell me the percentage of sales from promotions for Household Supplies in Zone 880 for the next quarter?
# AI: Call Movement API with {"product-name" = "Household Supplies", "location-name" = "Zone 880", "week" = "next quarter", metrics = ["sales"]} and Call Movement API with {"product-name" = "Household Supplies", "location-name" = "Zone 880", "week" = "next quarter", metrics = ["sales"], "promo" = "Y"} and Call Calculator API with {"operation" = "division", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
#
#
#
#
# Sales Comparison
# ----------------
# User: Give me a comparison of Eye/Ear Care sales for Zone 1000 this year versus last year.
# AI: Call Movement API with {"product-name" = "Eye/Ear Care", "location-name" = "Zone 1000", year = "last 1", "location-aggregate-level" = "week"} and Call Movement API with {"product-name" = "Eye/Ear Care", "location-name" = "Zone 1000", year = "current", "location-aggregate-level" = "week"}
#
#
# User: Can you show me the YoY change in sales for Zone 500 Beauty and Cosmetics?
# AI: Call Movement API with {"product-name" = "Beauty and Cosmetics", "location-name" = "Zone 500", year = "last 1", "location-aggregate-level" = "year"} and Call Movement API with {"product-name" = "Beauty and Cosmetics", "location-name" = "Zone 500", year = "current", "location-aggregate-level" = "year"} and Call Calculator API with {"operation" = "percentage change", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
#
# User: Provide me with a comparison of Snacks and Confectionery sales for Zone 150 over the last two years.
# AI: Call Movement API with {"product-name" = "Snacks and Confectionery", "location-name" = "Zone 150", year = "last 2", "location-aggregate-level" = "week"} and Call Movement API with {"product-name" = "Snacks and Confectionery", "location-name" = "Zone 150", year = "current", "location-aggregate-level" = "week"}
#
#
#
#
#
# Promotions
# ----------------
# User: Can you give me a list of upcoming items with a BOGO offer in the Home Decor category? Which of these items are on page 1 of the ad in Zone 670?
# AI: Call Promo API with {"product-name" = "Home Decor", "location-name" = "Zone 670", "week" = "upcoming", "type" = "BOGO", "page-no" = 1}
#
#
# User: Which products are planned to have a Buy One Get One Half Off offer in the next week for the Electronics category and in Zone 240?
# AI: Call Promo API with {"product-name" = "Electronics", "location-name" = "Zone 240", "week" = "next week", "type" = "BOGO Half Off"}
#
#
# User: Give me a list of items that will be on sale in the coming week in the Fashion category. Which of these items are on the front page of the ad in Zone 360?
# AI: Call Promo API with {"product-name" = "Fashion", "location-name" = "Zone 360", "week" = "coming week", "category" = "Fashion", "page-no" = 1}
#
#
# User: What are the upcoming products with a BOGO Free offer in the Health and Wellness category? Which of these products are available in Zone 520?
# AI: Call Promo API with {"product-name" = "Health and Wellness", "location-name" = "Zone 520", "week" = "upcoming", "type" = "BOGO Free"}
#
#
# User: Which items will be part of a Buy 2 Get 1 Free offer in the next few days in the Toys category in Zone 410?
# AI: Call Promo API with {"product-name" = "Toys", "location-name" = "Zone 410", "week" = "next few days", "type" = "Buy 2 Get 1 Free"}
#
#
# User: Can you provide me with a list of products planned to be on sale next week in the Beauty category? Which of these items are in Zone 980?
# AI: Call Promo API with {"product-name" = "Beauty", "location-name" = "Zone 980", "week" = "next week", "category" = "Beauty"}
#
#
# User: What products will be part of a 20% off promotion in the coming days in the Home Appliances category? Are any of these products available in Zone 120?
# AI: Call Promo API with {"product-name" = "Home Appliances", "location-name" = "Zone 120", "week" = "coming days", "type" = "20% off"}
#
#
# User: Which products are planned to have a BOGO 50% off offer in the next week in the Baby Care category? Are any of these products available in Zone 820?
# AI: Call Promo API with {"product-name" = "Baby Care", "location-name" = "Zone 820", "week" = "upcoming", "type" = "BOGO 50% off"}
#
#
# User: What are the upcoming products with a Buy 3 Get 1 Free offer in the Pet Supplies category? Which of these products are in Zone 710?
# AI: Call Promo API with {"product-name" = "Pet Supplies", "location-name" = "Zone 710", "week" = "next few days", "type" = "Buy 3 Get 1 Free"}
#
#
# User: Give me a list of items that will be on sale in the coming week in the Grocery category. Which of these items are on the back page of the ad in Zone 590?
# AI: Call Promo API with {"product-name" = "Grocery", "location-name" = "Zone 590", "week" = "coming week", "category" = "Grocery", "page-no" = "back"}
#
#
# User: Which products will be part of a Buy One Get One Free offer in the next few days in the Home Improvement category? Are any of these products available in Zone 380?
# AI: Call Promo API with {"product-name" = "Home Improvement", "location-name" = "Zone 380", "week" = "next few days", "type" = "BOGO Free"}
#
#
# User: Give me a list of upcoming items with a BOGO 25% off offer in the Toys category. Which of these items are in Zone 950?
# AI: Call Promo API with {"product-name" = "Toys", "location-name" = "Zone 950", "week" = "upcoming", "type" = "BOGO 25% off"}
#
#
# User: What products will be part of a 30% off promotion in the coming days in the Sports category? Are any of these products available in Zone 70?
# AI: Call Promo API with {"product-name" = "Sports", "location-name" = "Zone 70", "week" = "coming days", "type" = "30% off"}
#
#
# User: Which items are planned to be on sale next week in the Kitchen Appliances category? Are any of these items on the endcaps in Zone 890?
# AI: Call Promo API with {"product-name" = "Kitchen Appliances", "location-name" = "Zone 890", "week" = "next week", "category" = "Kitchen Appliances", "endcaps" = "yes"}
#
#
# User: Can you provide me with a list of products planned to be part of a Buy 2 Get 2 Free offer in the next few days in the Office Supplies category? Which of these products are available in Zone 580?
# AI: Call Promo API with {"product-name" = "Office Supplies", "location-name" = "Zone 580", "week" = "next few days", "type" = "Buy 2 Get 2 Free"}
#
#
# User: What are the upcoming products with a Buy One Get One 25% off offer in the Health and Beauty category? Which of these products are in Zone 420?
# AI: Call Promo API with {"product-name" = "Health and Beauty", "location-name" = "Zone 420", "week" = "upcoming", "type" = "BOGO 25% off"}
#
#
# User: Give me a list of items that will be part of a 10 for $10 promotion in the coming week in the Snacks category. Which of these items are on the side panels of the ad in Zone 300?
# AI: Call Promo API with {"product-name" = "Snacks", "location-name" = "Zone 300", "week" = "coming week", "type" = "10 for $10", "page-no" = "side panels"}

# %%
from random import shuffle

def create_context_chunks_from_dataframe(df, nsamples=3):
    contexts = []
    categories = df.Category.unique().tolist()
    for category in categories:
        category_context = [category, "----------------", ""]
        catdf = df[df.Category==category]
        sids = catdf.SynthId.unique().tolist()
        shuffle(sids)
        nsamples = min(nsamples, len(sids))
        for sid in sids[:nsamples]:
            udf = catdf[catdf.SynthId == sid].sort_values("UtteranceIndex")
            for i, row in udf.iterrows():
                category_context.append(f"{row.Role}: {row.Utterance}")
            category_context.append("")
            
        contexts.append("\n".join(category_context))

    return contexts

# %%
contexts = create_context_chunks_from_dataframe(df)
for c in contexts:
    print(c)
    print("_______________")
# Out:
# Movement/Sales
# ----------------
#
# User: What were the sales numbers for Men's Clothing in Zone 500 in Q3 of last year?
# AI: Call Movement API with {"product-name" = "Men's Clothing", "quarter" = 3, "metrics" = ["sales"], "location-name" = "Zone 500"}
#
# User: I want to see the sales numbers for Outdoor Gear in Zone 900 for the first half of this year.
# AI: Call Movement API with {"product-name" = "Outdoor Gear", "quarter" = "first half of the year", "metrics" = ["sales"], "location-name" = "Zone 900"}
#
# User: How much revenue was generated from Home Decor in Zone 750 in the first quarter of this year?
# AI: Call Movement API with {"product-name" = "Home Decor", "quarter" = 1, "metrics" = ["sales"], "location-name" = "Zone 750"}
#
# _______________
# Budget/Forecast
# ----------------
#
# User: What are the sales targets for Snacks in Zone 35 for the next quarter?
# AI: Call Budget API with {"product-name" = "Snacks", "quarter" = "next", "location-name" = "Zone 35"} and Call Forecast API with {"product-name" = "Snacks", "quarter" = "next", "location-name" = "Zone 35"}
#
# User: What are the sales targets for Canned Goods for the next six months in Zone 710?
# AI: Call Budget API with {"product-name" = "Canned Goods", "quarter" = "next-6-months", "location-name" = "Zone 710"} and Call Forecast API with {"product-name" = "Canned Goods", "quarter" = "next-6-months", "location-name" = "Zone 710"}
#
# User: What is the projected revenue for Beverages in Zone 20 for the next six months?
# AI: Call Budget API with {"product-name" = "Beverages", "quarter" = "next-6-months", "location-name" = "Zone 20"} and Call Forecast API with {"product-name" = "Beverages", "quarter" = "next-6-months", "location-name" = "Zone 20"}
#
# _______________
# KVI
# ----------------
#
# User: Can you give me a list of Secondary KVIs for Pet Care in Zone 710?
# AI: Call KVI API with {"product-name" = "Pet Care", "location-name" = "Zone 710", type = "Secondary"}
#
# User: Provide me with the Top KVIs for Toys and Games in Zone 880.
# AI: Call KVI API with {"product-name" = "Toys and Games", "location-name" = "Zone 880", type = "Primary"}
#
# User: What are the Secondary KVIs for Health and Wellness in Zone 15?
# AI: Call KVI API with {"product-name" = "Health and Wellness", "location-name" = "Zone 15", type = "Secondary"}
#
# _______________
# Price Change
# ----------------
#
# User: Can you provide me with a list of all products with a price change in the last four weeks for Frozen Foods in Zone 35?
# AI: Call Price API with {"product-name" = "Frozen Foods", "location-name" = "Zone 35", week = "last 4", change = "Y"}
#
# User: Can you give me a list of all items with a cost change in the last month for Beauty and Cosmetics in Zone 35?
# AI: Call Cost API with {"product-name" = "Beauty and Cosmetics", "location-name" = "Zone 35", week = "last month", change = "Y"}
#
# User: What are the products that have had a price change in the last week for Meat and Poultry in Zone 450?
# AI: Call Price API with {"product-name" = "Meat and Poultry", "location-name" = "Zone 450", week = "last week", change = "Y"}
#
# _______________
# Promotions Percent
# ----------------
#
# User: Can you provide me with the percentage of sales from promotions for Bakery products for the first half of the year in Zone 1?
# AI: Call Movement API with {"product-name" = "Bakery", "location-name" = "Zone 1", "start-date" = "01-01-YYYY", "end-date" = "06-30-YYYY", metrics = ["sales"]} and Call Movement API with {"product-name" = "Bakery", "location-name" = "Zone 1", "start-date" = "01-01-YYYY", "end-date" = "06-30-YYYY", metrics = ["sales"], "promo" = "Y"} and Call Calculator API with {"operation" = "division", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
# User: What percentage of our Frozen Foods sales are from promotions in Zone 1?
# AI: Call Movement API with {"product-name" = "Frozen Foods", "location-name" = "Zone 1", metrics = ["sales"]} and Call Movement API with {"product-name" = "Frozen Foods", "location-name" = "Zone 1", metrics = ["sales"], "promo" = "Y"} and Call Calculator API with {"operation" = "division", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
# User: How much of our Deli product sales are from promotions in the current month in Zone 1?
# AI: Call Movement API with {"product-name" = "Deli", "location-name" = "Zone 1", "week" = "current month", metrics = ["sales"]} and Call Movement API with {"product-name" = "Deli", "location-name" = "Zone 1", "week" = "current month", metrics = ["sales"], "promo" = "Y"} and Call Calculator API with {"operation" = "division", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
# _______________
# Sales Comparison
# ----------------
#
# User: Give me a comparison of Eye/Ear Care sales for Zone 1000 this year versus last year.
# AI: Call Movement API with {"product-name" = "Eye/Ear Care", "location-name" = "Zone 1000", year = "last 1", "location-aggregate-level" = "week"} and Call Movement API with {"product-name" = "Eye/Ear Care", "location-name" = "Zone 1000", year = "current", "location-aggregate-level" = "week"}
#
# User: Can you show me the YoY change in sales for Zone 500 Beauty and Cosmetics?
# AI: Call Movement API with {"product-name" = "Beauty and Cosmetics", "location-name" = "Zone 500", year = "last 1", "location-aggregate-level" = "year"} and Call Movement API with {"product-name" = "Beauty and Cosmetics", "location-name" = "Zone 500", year = "current", "location-aggregate-level" = "year"} and Call Calculator API with {"operation" = "percentage change", "data" = [Movement API Response 2, Movement API Response 1], "format" = "percent"}
#
# User: Provide me with a comparison of Snacks and Confectionery sales for Zone 150 over the last two years.
# AI: Call Movement API with {"product-name" = "Snacks and Confectionery", "location-name" = "Zone 150", year = "last 2", "location-aggregate-level" = "week"} and Call Movement API with {"product-name" = "Snacks and Confectionery", "location-name" = "Zone 150", year = "current", "location-aggregate-level" = "week"}
#
# _______________
# Promotions
# ----------------
#
# User: What are the upcoming products with a Buy One Get One 25% off offer in the Health and Beauty category? Which of these products are in Zone 420?
# AI: Call Promo API with {"product-name" = "Health and Beauty", "location-name" = "Zone 420", "week" = "upcoming", "type" = "BOGO 25% off"}
#
# User: Can you provide me with a list of products planned to be part of a Buy 2 Get 2 Free offer in the next few days in the Office Supplies category? Which of these products are available in Zone 580?
# AI: Call Promo API with {"product-name" = "Office Supplies", "location-name" = "Zone 580", "week" = "next few days", "type" = "Buy 2 Get 2 Free"}
#
# User: Which items are planned to be on sale next week in the Kitchen Appliances category? Are any of these items on the endcaps in Zone 890?
# AI: Call Promo API with {"product-name" = "Kitchen Appliances", "location-name" = "Zone 890", "week" = "next week", "category" = "Kitchen Appliances", "endcaps" = "yes"}
#
# _______________
